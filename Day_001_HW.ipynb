# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
#    答: 我找的是關於「鐵達尼號」的一組資料集，裡頭包含乘客性別、年齡、存活狀態、船票等級以及乘船地點等等，因為這
#        筆數據資料，可以讓我透過關聯規則Apriori演算法，找到乘客生存狀態與性別、年齡和乘船地點之間的關係，並且從
#        這些關係去挖掘出對我有價值的資訊，故我認為這筆數據很重要。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#    答:資料由kaggle的競賽所提供之資訊，至於用何種方式蒐集，應該是直接拿取鐵達尼號沈船後所遺留之資訊。
#
# 3. 蒐集而來的資料型態為何
#
#    答:資料的欄位部分，像年齡與船艙號碼的數據是有缺漏而不完整的。整體的資料型態為結構化與非結構混和，擁有表格、
#        數值和文字，總共有11欄位，1309筆數據。
#
# 4. 這組資料想解決的問題如何評估
#
#    答: 承第一題我所陳述的，自己主要是想探討鐵達尼號乘客生存狀態與其他變數(像是年齡、性別、乘船地點)之間的關
#        係，透過Apriori中的信賴度與支持度指標來進行資料裡變數之間的探討，而此資料集也剛好為我所需之資料集，可以
#        助我釐清變數之間德關係。

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#    答: 我認知上的提升業績為「載客數的增長」，故將「如何讓我車隊的載客數增長」作為我的核心問題。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#    答: 「大眾運輸站點的人流數據、特定區域的飯店和景點的人流數據」都會影響車隊的載客量。
#         關於以上數據地收集，可以使用政府開放的open data，可以知道大眾運輸站點，觀光景
#         點和飯店住房率等等。
#
#
# 3. 蒐集而來的資料型態為何
#
#    答:資料型態為結構化和非結構化混和，擁有表格、文字和數值。網上open data的高雄捷運公司就有提供數據，包含營運
#       日、星期、紅線運量、橘線運量和總運量的欄位；高雄市觀光景點和飯店，政府也提供了人流與住房數據。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#    答: 透過公司去了解過往到現在的載客數，如發現擁有載客數的平均數遞減的現象，並且影響到業績，就可以驗證「如何讓
#        載客數增加」的問題成立。

# %% [markdown]
# # 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    """
    請完成這個 Function 後往下執行
    """
    MSE=sum((abs(y-y_hat))**2)/len(y)
    return MSE

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 215.625
# The Mean absolute error is 11.798
